# %%
import pandas as pd

# %%
df = pd.read_excel('0.xlsx')
df.head()
# Out:
#         昵称                                               评论文本  \
# 0    辣条少女。  图一是奶酪和火腿因为别人请客的名字都记不住，奶酪QQ的太喜欢啦！披萨是黑松露的什么什么，真的...
# 1    小仙女妈妈  一直关注的一家意大利餐厅点评上搜了电话提前预定了座位，老板的普通话真标准每道菜都好吃[薄荷]...
# 2  爱西瓜味的泡芙  [薄荷]环境：地址：赤峰道小店不大餐桌不是很多整体环境不错氛围比较安静[服务铃]服务：老板是...
# 3  爱吃蛋糕的小喵  种草了很久的Restaurant坐标➺Osteria意大利餐厅🇮🇹位置📍赤峰道86号（赤峰道...
# 4      贝壳滩  周末出来走走，又来了这家意大利餐厅。上次来可能一两年了，好久了。店里都重新装修了，以前来只有...
#
#                评论时间   评分
# 0  2022-03-15 17:27  5.0
# 1  2022-03-12 18:53  5.0
# 2  2022-03-17 10:12  5.0
# 3  2022-02-24 21:48  5.0
# 4  2022-02-27 18:35  5.0

# %%
content = df['评论文本']
content.head()
# Out:
# 0    图一是奶酪和火腿因为别人请客的名字都记不住，奶酪QQ的太喜欢啦！披萨是黑松露的什么什么，真的...
# 1    一直关注的一家意大利餐厅点评上搜了电话提前预定了座位，老板的普通话真标准每道菜都好吃[薄荷]...
# 2    [薄荷]环境：地址：赤峰道小店不大餐桌不是很多整体环境不错氛围比较安静[服务铃]服务：老板是...
# 3    种草了很久的Restaurant坐标➺Osteria意大利餐厅🇮🇹位置📍赤峰道86号（赤峰道...
# 4    周末出来走走，又来了这家意大利餐厅。上次来可能一两年了，好久了。店里都重新装修了，以前来只有...
# Name: 评论文本, dtype: object

# %%
content.drop_duplicates(keep='first', inplace=True)
content
# Out:
# 0      图一是奶酪和火腿因为别人请客的名字都记不住，奶酪QQ的太喜欢啦！披萨是黑松露的什么什么，真的...
# 1      一直关注的一家意大利餐厅点评上搜了电话提前预定了座位，老板的普通话真标准每道菜都好吃[薄荷]...
# 2      [薄荷]环境：地址：赤峰道小店不大餐桌不是很多整体环境不错氛围比较安静[服务铃]服务：老板是...
# 3      种草了很久的Restaurant坐标➺Osteria意大利餐厅🇮🇹位置📍赤峰道86号（赤峰道...
# 4      周末出来走走，又来了这家意大利餐厅。上次来可能一两年了，好久了。店里都重新装修了，以前来只有...
#                              ...
# 760    很崴脚小姐妹一起探店，店面不大但是风格蛮不错的，很清净。有吧台坐，后面一面酒。菜的味道都很不...
# 761    都收藏好久了，终于打卡。很喜欢店的氛围，很舒服很自在，但是菜品真的不太稳。又遇上去的两次都不...
# 762    饿成狗了，选了这么好吃的餐厅，真的是太幸福了！本来就特别想吃ravioli，一看还真有，简直...
# 763    据说它是哏儿都意大利餐第一名排名，还有帅哥老板果断来吃吃看。因为桌子较少所以需要提前预约，我...
# 764    门脸很小，老板是歪果仁～但是中文非常流利，环境幽暗，适合约会，服务也比较周到，眼镜小哥一直观...
# Name: 评论文本, Length: 765, dtype: object

# %%
import re
def clear_characters(text):
    return re.sub('\W', '', text)

# %%
content = content.astype(str)
content = content.apply(clear_characters)
content.dropna(how='any', inplace=True)
content
# Out:
# 0      图一是奶酪和火腿因为别人请客的名字都记不住奶酪QQ的太喜欢啦披萨是黑松露的什么什么真的也是很...
# 1      一直关注的一家意大利餐厅点评上搜了电话提前预定了座位老板的普通话真标准每道菜都好吃薄荷环境在...
# 2      薄荷环境地址赤峰道小店不大餐桌不是很多整体环境不错氛围比较安静服务铃服务老板是意大利人服务很...
# 3      种草了很久的Restaurant坐标Osteria意大利餐厅位置赤峰道86号赤峰道和河北路交...
# 4      周末出来走走又来了这家意大利餐厅上次来可能一两年了好久了店里都重新装修了以前来只有一楼店铺不...
#                              ...
# 760    很崴脚小姐妹一起探店店面不大但是风格蛮不错的很清净有吧台坐后面一面酒菜的味道都很不错风干牛肉...
# 761    都收藏好久了终于打卡很喜欢店的氛围很舒服很自在但是菜品真的不太稳又遇上去的两次都不能喝酒就很...
# 762    饿成狗了选了这么好吃的餐厅真的是太幸福了本来就特别想吃ravioli一看还真有简直跟中了彩票...
# 763    据说它是哏儿都意大利餐第一名排名还有帅哥老板果断来吃吃看因为桌子较少所以需要提前预约我预约的...
# 764    门脸很小老板是歪果仁但是中文非常流利环境幽暗适合约会服务也比较周到眼镜小哥一直观察着客人的用...
# Name: 评论文本, Length: 765, dtype: object

# %%
import jieba
import jieba.analyse
import matplotlib.pyplot as plt
from PIL import Image
from matplotlib.font_manager import FontProperties

# %%
cut_words = ""
for line in content:
    line.strip('\n')
    seg_list = jieba.cut(line,cut_all=False)
    cut_words += (" ".join(seg_list))

jieba.analyse.set_stop_words('stopwords_cn.txt')   # 停用词词典

# 提取主题词 返回的词频其实就是TF-IDF
keywords = jieba.analyse.extract_tags(cut_words,
                                      topK=100,
                                      withWeight=True,
                                      allowPOS=('a','e','n','nr','ns', 'v')) #词性 形容词 叹词 名词 动词


# 数据存储
pd.DataFrame(keywords, columns=['词语','重要性']).to_excel('TF_IDF关键词前100.xlsx')

# keyword本身包含两列数据
ss = pd.DataFrame(keywords,columns = ['词语','重要性'])


plt.figure(figsize=(10,6),dpi=300)
plt.rcParams['font.sans-serif'] = ['SimHei']#支持中文
plt.title('TF-IDF Ranking')
plt.barh(range(len(ss.重要性[:25][::-1])),ss.重要性[:25][::-1])
plt.yticks(range(len(ss.词语[:25][::-1])),ss.词语[:25][::-1])
plt.xlabel('Importance')
plt.savefig('词性重要度排名.jpg')

# %%
# coding=utf-8
import jieba
import re
import time
from collections import Counter


def is_all_chinese(strs):
    for _char in strs:
        if not '\u4e00' <= _char <= '\u9fa5':
            return False
    return True

cut_words = ""
all_words = ""
f = open('C-class-fenci.txt', 'w', encoding='utf-8')
for line in content:
    line = line.strip('\n')
    #停用词过滤
    line = re.sub('[0-9’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~\s]+', "", line)
    seg_list = jieba.cut(line, cut_all=False)
    cut_words = (" ".join(seg_list))

    #计算关键词
    all_words = cut_words.split()
    c = Counter()
    for x in all_words:
        if len(x)>1 and x != '\r\n':
            if is_all_chinese(x) == True:
                c[x] += 1
    #Top50
    output = ""
    #print('\n词频统计结果：')
    for (k,v) in c.most_common():
        #print("%s:%d"%(k,v))
        output += k + " "
    
    f.write(output+"\n")
else:
    f.close()

# %%
stop_words = [] 
    
with open("stopwords_cn.txt", 'r', encoding='utf-8') as f:
    lines = f.readlines()
    for line in lines:
        stop_words.append(line.strip())

# %%
#coding: utf-8
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

corpus = []

# 读取预料 一行预料为一个文档
for line in open('C-class-fenci.txt', 'r',encoding='utf-8').readlines():
    corpus.append(line.strip())
        

# 设置特征数
n_features = 2000

tf_vectorizer = TfidfVectorizer(strip_accents = 'unicode',
                                max_features=n_features,
                                stop_words=stop_words,
                                max_df = 0.99,
                                min_df = 0.002) #去除文档内出现几率过大或过小的词汇

tf = tf_vectorizer.fit_transform(corpus)

print(tf)
# Out:
#   (0, 584)	0.1464837592700259
#   (0, 676)	0.16178559022014444
#   (0, 1056)	0.22045652774561542
#   (0, 912)	0.18990774587253448
#   (0, 517)	0.23528572600418085
#   (0, 1885)	0.22725034531524888
#   (0, 1884)	0.2510053096186963
#   (0, 1505)	0.1300067961585383
#   (0, 1073)	0.27566901902679236
#   (0, 175)	0.18836118100922936
#   (0, 68)	0.21189957202127394
#   (0, 691)	0.22045652774561542
#   (0, 1953)	0.27566901902679236
#   (0, 153)	0.2510053096186963
#   (0, 102)	0.2577991271883298
#   (0, 959)	0.16899716045417482
#   (0, 1368)	0.11227188934478032
#   (0, 1991)	0.2093804534767863
#   (0, 595)	0.10347700299336679
#   (0, 538)	0.2025866359071528
#   (0, 1269)	0.09986421601908092
#   (0, 785)	0.2510053096186963
#   (0, 205)	0.1710008043959728
#   (0, 1311)	0.11016022432902005
#   (0, 1034)	0.08078678080528108
#   :	:
#   (764, 1345)	0.08474360825575752
#   (764, 1760)	0.07423613186448444
#   (764, 242)	0.11004063891336109
#   (764, 1326)	0.0686203730180513
#   (764, 1060)	0.05079954804549909
#   (764, 1576)	0.1130587343690283
#   (764, 86)	0.08666835710555915
#   (764, 178)	0.05689452219331331
#   (764, 1229)	0.08666835710555915
#   (764, 560)	0.0417037635465132
#   (764, 1355)	0.07767202372046055
#   (764, 499)	0.06394140943055693
#   (764, 1206)	0.0440927714186793
#   (764, 1089)	0.07394820259891766
#   (764, 497)	0.06085450983747595
#   (764, 956)	0.0943740281288921
#   (764, 141)	0.04575602588231319
#   (764, 1328)	0.053180921348537954
#   (764, 24)	0.06585799276665474
#   (764, 1140)	0.05284103311368354
#   (764, 1491)	0.03948095403510785
#   (764, 1924)	0.052617247704486274
#   (764, 1269)	0.05121427787749906
#   (764, 1311)	0.05649447384392523
#   (764, 767)	0.05785646062852085
# D:\rgzn\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['11', '12', '13', '14', '15', '16', '17', '18', '19', '1a', '1b', '1c', '1d', '1e', '1f', '1g', '1h', '1i', '1o', '21', '210', '22', '23', '24', '25', '26', '27', '28', '2a', '2b', '2c', '2d', '2e', '2f', '2g', '2h', '2i', '2j', '31', '310', '3a', '3b', '3c', '3d', '3e', '3f', '3g', '3h', '4a', '4b', '4c', '4d', '4e', '5a', '5b', '5d', '5e', '5f', 'iii', 'lex', 'li', 'ng昉', 'zxfitl'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
from sklearn.decomposition import LatentDirichletAllocation

# 设置主题数
n_topics = 3

lda = LatentDirichletAllocation(n_components=n_topics,
                                max_iter=100,
                                learning_method='online',
                                learning_offset=50,
                                random_state=0)
lda.fit(tf)

# 显示主题数 model.topic_word_
print(lda.components_)
# 几个主题就是几行 多少个关键词就是几列 
print(lda.components_.shape)                         

# 计算困惑度
print(u'困惑度：')
print(lda.perplexity(tf,sub_sampling = False))



# 主题-关键词分布
def print_top_words(model, tf_feature_names, n_top_words):
    for topic_idx,topic in enumerate(model.components_):  # lda.component相当于model.topic_word_
        print('Topic #%d:' % topic_idx)
        print(' '.join([tf_feature_names[i] for i in topic.argsort()[:-n_top_words-1:-1]]))
        print("")

# 定义好函数之后 暂定每个主题输出前20个关键词
n_top_words = 20                                       
tf_feature_names = tf_vectorizer.get_feature_names()
# 调用函数
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# [[0.33770151 0.33614392 0.33637638 ... 0.33821641 0.33583142 0.3361143 ]
#  [1.05070332 1.12631905 1.28187198 ... 0.88743672 1.24129886 0.94572324]
#  [0.33771813 0.336155   0.33638797 ... 0.33823638 0.33584039 0.33612747]]
# (3, 2000)
# 困惑度：
# 2793.2251440647315
# Topic #0:
# 无可挑剔 太贵 一周年 一顿饭 熏火腿 庆祝 饱饱 薄片 特别 大声 挺不错 尴尬 好吃 料理 中国 外教 七夕 留意 绝绝子 买卖
#
# Topic #1:
# 老板 不错 味道 好吃 披萨 意大利 沙拉 菜品 餐厅 推荐 喜欢 环境 服务 火腿 中文 猪排 牛排 提前 真的 这家
#
# Topic #2:
# 大声 料理 外教 七夕 留意 绝绝子 买卖 两年 不太惯 饭后 太绝 助消化 角落 大片 走心 天津市 别有洞天 太久 真材实料 无可挑剔

# %%
import pyLDAvis
import pyLDAvis.sklearn


data = pyLDAvis.sklearn.prepare(lda,tf,tf_vectorizer)
print(data)


pyLDAvis.save_html(data,' lda.html')
# Out:
# D:\rgzn\lib\site-packages\past\types\oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Iterable
# D:\rgzn\lib\site-packages\past\builtins\misc.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Mapping
# PreparedData(topic_coordinates=              x    y  topics  cluster       Freq
# topic
# 1      0.064462 -0.0       1        1  88.756153
# 0     -0.032505 -0.0       2        1   5.636865
# 2     -0.031957 -0.0       3        1   5.606982, topic_info=      Term      Freq     Total Category  logprob  loglift
# 1093  无可挑剔  1.000000  1.000000  Default  30.0000  30.0000
# 742     太贵  1.000000  1.000000  Default  29.0000  29.0000
# 1045   挺不错  2.000000  2.000000  Default  28.0000  28.0000
# 1087    料理  2.000000  2.000000  Default  27.0000  27.0000
# 882     尴尬  2.000000  2.000000  Default  26.0000  26.0000
# ...    ...       ...       ...      ...      ...      ...
# 730     太帅  0.106493  1.900116   Topic3  -7.5937  -0.0004
# 1283    点菜  0.106474  2.327751   Topic3  -7.5939  -0.2036
# 480     友善  0.106453  1.398083   Topic3  -7.5941   0.3060
# 375     出彩  0.106453  1.183427   Topic3  -7.5941   0.4727
# 1103    日本  0.106452  2.500506   Topic3  -7.5941  -0.2754
#
# [223 rows x 6 columns], token_table=      Topic      Freq  Term
# term
# 23        1  1.063043  一如既往
# 24        1  0.968384    一家
# 35        1  1.199641    一栋
# 39        1  1.258508    一步
# 69        1  0.918081    七夕
# ...     ...       ...   ...
# 1906      1  0.967001    预约
# 1924      1  0.991759    餐厅
# 1932      1  0.838395    饭后
# 1943      1  0.763907    饱饱
# 1997      1  1.130531    默默
#
# [113 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1, 3])
