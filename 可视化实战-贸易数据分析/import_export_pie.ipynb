# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.globals import ThemeType



#进口
x_data1 = ['美国','英国','德国','加拿大','日本','中国','法国','意大利','印度','西班牙','其他国家']
y_data1 = [161994.20,733.55,4926.8,19195.35,226.4,13693,1483.2,1957.35,1122.25,1963.8,float(349021.65-207295.9)]
data_pair_1 = [(i,j) for i, j in zip(x_data1,y_data1)]

#出口
x_data2 = ['美国','英国','德国','加拿大','日本','中国','法国','意大利','印度','西班牙','其他国家']
y_data2 = [586.45,10288.35,304.75,11070.65,4317.6,23650.40,21893.5,1957.35,1076.3,5344.2,float(365692.1-80489.55)]

data_pair_2 = [(i,j) for i, j in zip(x_data2,y_data2)]


c = (
    Pie(init_opts=opts.InitOpts(width="1300px", height="600px",theme=ThemeType.MACARONS))
    .add(
        series_name="进口",
        data_pair=data_pair_1,
        radius=["50%", "70%"],
        center=["25%", "50%"],
        label_opts=opts.LabelOpts(is_show=True),
    )
    .add(
        series_name="出口",
        data_pair=data_pair_2,
        radius=["50%", "70%"],
        center=["75%", "50%"],
        label_opts=opts.LabelOpts(is_show=True),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="近20年以来的进出口贸易环状图"))
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item", formatter="{a} <br/>{b}: {d}%"
        ),
    )
)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons'
#         }
#     });
# </script>
#
#         <div id="95467700d0174409be96e13317ba9823" style="width:1300px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'macarons'], function(echarts) {
#                 var chart_95467700d0174409be96e13317ba9823 = echarts.init(
#                     document.getElementById('95467700d0174409be96e13317ba9823'), 'macarons', {renderer: 'canvas'});
#                 var option_95467700d0174409be96e13317ba9823 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u8fdb\u53e3",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7f8e\u56fd",
#                     "value": 161994.2
#                 },
#                 {
#                     "name": "\u82f1\u56fd",
#                     "value": 733.55
#                 },
#                 {
#                     "name": "\u5fb7\u56fd",
#                     "value": 4926.8
#                 },
#                 {
#                     "name": "\u52a0\u62ff\u5927",
#                     "value": 19195.35
#                 },
#                 {
#                     "name": "\u65e5\u672c",
#                     "value": 226.4
#                 },
#                 {
#                     "name": "\u4e2d\u56fd",
#                     "value": 13693
#                 },
#                 {
#                     "name": "\u6cd5\u56fd",
#                     "value": 1483.2
#                 },
#                 {
#                     "name": "\u610f\u5927\u5229",
#                     "value": 1957.35
#                 },
#                 {
#                     "name": "\u5370\u5ea6",
#                     "value": 1122.25
#                 },
#                 {
#                     "name": "\u897f\u73ed\u7259",
#                     "value": 1963.8
#                 },
#                 {
#                     "name": "\u5176\u4ed6\u56fd\u5bb6",
#                     "value": 141725.75000000003
#                 }
#             ],
#             "radius": [
#                 "50%",
#                 "70%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": "{a} <br/>{b}: {d}%",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "pie",
#             "name": "\u51fa\u53e3",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7f8e\u56fd",
#                     "value": 586.45
#                 },
#                 {
#                     "name": "\u82f1\u56fd",
#                     "value": 10288.35
#                 },
#                 {
#                     "name": "\u5fb7\u56fd",
#                     "value": 304.75
#                 },
#                 {
#                     "name": "\u52a0\u62ff\u5927",
#                     "value": 11070.65
#                 },
#                 {
#                     "name": "\u65e5\u672c",
#                     "value": 4317.6
#                 },
#                 {
#                     "name": "\u4e2d\u56fd",
#                     "value": 23650.4
#                 },
#                 {
#                     "name": "\u6cd5\u56fd",
#                     "value": 21893.5
#                 },
#                 {
#                     "name": "\u610f\u5927\u5229",
#                     "value": 1957.35
#                 },
#                 {
#                     "name": "\u5370\u5ea6",
#                     "value": 1076.3
#                 },
#                 {
#                     "name": "\u897f\u73ed\u7259",
#                     "value": 5344.2
#                 },
#                 {
#                     "name": "\u5176\u4ed6\u56fd\u5bb6",
#                     "value": 285202.55
#                 }
#             ],
#             "radius": [
#                 "50%",
#                 "70%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": "{a} <br/>{b}: {d}%",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7f8e\u56fd",
#                 "\u82f1\u56fd",
#                 "\u5fb7\u56fd",
#                 "\u52a0\u62ff\u5927",
#                 "\u65e5\u672c",
#                 "\u4e2d\u56fd",
#                 "\u6cd5\u56fd",
#                 "\u610f\u5927\u5229",
#                 "\u5370\u5ea6",
#                 "\u897f\u73ed\u7259",
#                 "\u5176\u4ed6\u56fd\u5bb6"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u8fd120\u5e74\u4ee5\u6765\u7684\u8fdb\u51fa\u53e3\u8d38\u6613\u73af\u72b6\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_95467700d0174409be96e13317ba9823.setOption(option_95467700d0174409be96e13317ba9823);
#         });
#     </script>
